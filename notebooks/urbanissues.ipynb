# %%
import os
import shutil
import yaml
import cv2
import numpy as np
import seaborn as sns
import random
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw
from pathlib import Path
from collections import Counter, defaultdict
from ultralytics import YOLO
from sklearn.model_selection import train_test_split
from tqdm import tqdm
# import tqdm
import glob
# import PIL
# import ultralytics
# import sklearn
# import sys
# import matplotlib

# %%
# KAGGLE_INPUT = Path('/kaggle/input/urban-issues-dataset')
# KAGGLE_WORKING = Path('/kaggle/working')

DATASET_INPUT = Path("../data/res")
OUTPUT_PATH = Path("../outputs")

# Check dataset structure
print("Dataset structure:")
print(f"Input path: {DATASET_INPUT}")
print(f"Working path: {OUTPUT_PATH}")

# # List available datasets
print("\n Available datasets:")
for item in os.listdir(DATASET_INPUT):
    print(f"  - {item}")
# Out:
# Dataset structure:
# Input path: ..\data\res
# Working path: ..\outputs
#
#  Available datasets:
#   - config.yaml
#   - Damaged concrete structures
#   - DamagedElectricalPoles
#   - DamagedRoadSigns
#   - DeadAnimalsPollution
#   - FallenTrees
#   - Garbage
#   - Graffitti
#   - IllegalParking
#   - Potholes and RoadCracks

# %%
dataset_path = DATASET_INPUT

print("\nExploring dataset structure:")
for root, dirs, files in os.walk(dataset_path):
    print(f"\n{root}")
    for d in dirs[:5]:
        print(f"  file {d}")
    if files:
        print(f"  docs {len(files)} files")
    if len(dirs) > 5:
        print(f"  ... and {len(dirs)-5} more directories")
# Out:
# Exploring dataset structure:
#
# ..\data\res
#   file Damaged concrete structures
#   file DamagedElectricalPoles
#   file DamagedRoadSigns
#   file DeadAnimalsPollution
#   file FallenTrees
#   docs 1 files
#   ... and 4 more directories
#
# ..\data\res\Damaged concrete structures
#   file Damaged concrete structures
#
# ..\data\res\Damaged concrete structures\Damaged concrete structures
#   file test
#   file train
#   file valid
#
# ..\data\res\Damaged concrete structures\Damaged concrete structures\test
#   file images
#   file labels
#
# ..\data\res\Damaged concrete structures\Damaged concrete structures\test\images
#   docs 1222 files
#
# ..\data\res\Damaged concrete structures\Damaged concrete structures\test\labels
#   docs 1222 files
#
# ..\data\res\Damaged concrete structures\Damaged concrete structures\train
#   file images
#   file labels
#
# ..\data\res\Damaged concrete structures\Damaged concrete structures\train\images
#   docs 9315 files
#
# ..\data\res\Damaged concrete structures\Damaged concrete structures\train\labels
#   docs 9315 files
#
# ..\data\res\Damaged concrete structures\Damaged concrete structures\valid
#   file images
#   file labels
#
# ..\data\res\Damaged concrete structures\Damaged concrete structures\valid\images
#   docs 1228 files
#
# ..\data\res\Damaged concrete structures\Damaged concrete structures\valid\labels
#   docs 1228 files
#
# ..\data\res\DamagedElectricalPoles
#   file DamagedElectricalPoles
#
# ..\data\res\DamagedElectricalPoles\DamagedElectricalPoles
#   file test
#   file train
#   file valid
#
# ..\data\res\DamagedElectricalPoles\DamagedElectricalPoles\test
#   file images
#   file labels
#
# ..\data\res\DamagedElectricalPoles\DamagedElectricalPoles\test\images
#   docs 328 files
#
# ..\data\res\DamagedElectricalPoles\DamagedElectricalPoles\test\labels
#   docs 328 files
#
# ..\data\res\DamagedElectricalPoles\DamagedElectricalPoles\train
#   file images
#   file labels
#
# ..\data\res\DamagedElectricalPoles\DamagedElectricalPoles\train\images
#   docs 7271 files
#
# ..\data\res\DamagedElectricalPoles\DamagedElectricalPoles\train\labels
#   docs 7271 files
#
# ..\data\res\DamagedElectricalPoles\DamagedElectricalPoles\valid
#   file images
#   file labels
#
# ..\data\res\DamagedElectricalPoles\DamagedElectricalPoles\valid\images
#   docs 513 files
#
# ..\data\res\DamagedElectricalPoles\DamagedElectricalPoles\valid\labels
#   docs 513 files
#
# ..\data\res\DamagedRoadSigns
#   file DamagedRoadSigns
#
# ..\data\res\DamagedRoadSigns\DamagedRoadSigns
#   file test
#   file train
#   file valid
#   docs 3 files
#
# ..\data\res\DamagedRoadSigns\DamagedRoadSigns\test
#   file images
#   file labels
#
# ..\data\res\DamagedRoadSigns\DamagedRoadSigns\test\images
#   docs 39 files
#
# ..\data\res\DamagedRoadSigns\DamagedRoadSigns\test\labels
#   docs 39 files
#
# ..\data\res\DamagedRoadSigns\DamagedRoadSigns\train
#   file images
#   file labels
#
# ..\data\res\DamagedRoadSigns\DamagedRoadSigns\train\images
#   docs 2267 files
#
# ..\data\res\DamagedRoadSigns\DamagedRoadSigns\train\labels
#   docs 2267 files
#
# ..\data\res\DamagedRoadSigns\DamagedRoadSigns\valid
#   file images
#   file labels
#
# ..\data\res\DamagedRoadSigns\DamagedRoadSigns\valid\images
#   docs 43 files
#
# ..\data\res\DamagedRoadSigns\DamagedRoadSigns\valid\labels
#   docs 43 files
#
# ..\data\res\DeadAnimalsPollution
#   file DeadAnimalsPollution
#
# ..\data\res\DeadAnimalsPollution\DeadAnimalsPollution
#   file test
#   file train
#   file valid
#
# ..\data\res\DeadAnimalsPollution\DeadAnimalsPollution\test
#   file images
#   file labels
#
# ..\data\res\DeadAnimalsPollution\DeadAnimalsPollution\test\images
#   docs 16 files
#
# ..\data\res\DeadAnimalsPollution\DeadAnimalsPollution\test\labels
#   docs 16 files
#
# ..\data\res\DeadAnimalsPollution\DeadAnimalsPollution\train
#   file images
#   file labels
#
# ..\data\res\DeadAnimalsPollution\DeadAnimalsPollution\train\images
#   docs 172 files
#
# ..\data\res\DeadAnimalsPollution\DeadAnimalsPollution\train\labels
#   docs 172 files
#
# ..\data\res\DeadAnimalsPollution\DeadAnimalsPollution\valid
#   file images
#   file labels
#
# ..\data\res\DeadAnimalsPollution\DeadAnimalsPollution\valid\images
#   docs 32 files
#
# ..\data\res\DeadAnimalsPollution\DeadAnimalsPollution\valid\labels
#   docs 32 files
#
# ..\data\res\FallenTrees
#   file FallenTrees
#
# ..\data\res\FallenTrees\FallenTrees
#   file test
#   file train
#   file valid
#
# ..\data\res\FallenTrees\FallenTrees\test
#   file images
#   file labels
#
# ..\data\res\FallenTrees\FallenTrees\test\images
#   docs 1632 files
#
# ..\data\res\FallenTrees\FallenTrees\test\labels
#   docs 1632 files
#
# ..\data\res\FallenTrees\FallenTrees\train
#   file images
#   file labels
#
# ..\data\res\FallenTrees\FallenTrees\train\images
#   docs 8500 files
#
# ..\data\res\FallenTrees\FallenTrees\train\labels
#   docs 8500 files
#
# ..\data\res\FallenTrees\FallenTrees\valid
#   file images
#   file labels
#
# ..\data\res\FallenTrees\FallenTrees\valid\images
#   docs 982 files
#
# ..\data\res\FallenTrees\FallenTrees\valid\labels
#   docs 982 files
#
# ..\data\res\Garbage
#   file Garbage
#
# ..\data\res\Garbage\Garbage
#   file test
#   file train
#   file valid
#
# ..\data\res\Garbage\Garbage\test
#   file images
#   file labels
#
# ..\data\res\Garbage\Garbage\test\images
#   docs 337 files
#
# ..\data\res\Garbage\Garbage\test\labels
#   docs 337 files
#
# ..\data\res\Garbage\Garbage\train
#   file images
#   file labels
#
# ..\data\res\Garbage\Garbage\train\images
#   docs 3133 files
#
# ..\data\res\Garbage\Garbage\train\labels
#   docs 3131 files
#
# ..\data\res\Garbage\Garbage\valid
#   file images
#   file labels
#
# ..\data\res\Garbage\Garbage\valid\images
#   docs 660 files
#
# ..\data\res\Garbage\Garbage\valid\labels
#   docs 660 files
#
# ..\data\res\Graffitti
#   file Graffitti
#
# ..\data\res\Graffitti\Graffitti
#   file test
#   file train
#   file valid
#
# ..\data\res\Graffitti\Graffitti\test
#   file images
#   file labels
#
# ..\data\res\Graffitti\Graffitti\test\images
#   docs 210 files
#
# ..\data\res\Graffitti\Graffitti\test\labels
#   docs 210 files
#
# ..\data\res\Graffitti\Graffitti\train
#   file images
#   file labels
#
# ..\data\res\Graffitti\Graffitti\train\images
#   docs 1704 files
#
# ..\data\res\Graffitti\Graffitti\train\labels
#   docs 1704 files
#
# ..\data\res\Graffitti\Graffitti\valid
#   file images
#   file labels
#
# ..\data\res\Graffitti\Graffitti\valid\images
#   docs 214 files
#
# ..\data\res\Graffitti\Graffitti\valid\labels
#   docs 214 files
#
# ..\data\res\IllegalParking
#   file IllegalParking
#
# ..\data\res\IllegalParking\IllegalParking
#   file test
#   file train
#   file valid
#   docs 3 files
#
# ..\data\res\IllegalParking\IllegalParking\test
#   file images
#   file labels
#
# ..\data\res\IllegalParking\IllegalParking\test\images
#   docs 7 files
#
# ..\data\res\IllegalParking\IllegalParking\test\labels
#   docs 7 files
#
# ..\data\res\IllegalParking\IllegalParking\train
#   file images
#   file labels
#
# ..\data\res\IllegalParking\IllegalParking\train\images
#   docs 57 files
#
# ..\data\res\IllegalParking\IllegalParking\train\labels
#   docs 57 files
#
# ..\data\res\IllegalParking\IllegalParking\valid
#   file images
#   file labels
#
# ..\data\res\IllegalParking\IllegalParking\valid\images
#   docs 3 files
#
# ..\data\res\IllegalParking\IllegalParking\valid\labels
#   docs 3 files
#
# ..\data\res\Potholes and RoadCracks
#   file Potholes and RoadCracks
#
# ..\data\res\Potholes and RoadCracks\Potholes and RoadCracks
#   file test
#   file train
#   file valid
#
# ..\data\res\Potholes and RoadCracks\Potholes and RoadCracks\test
#   file images
#   file labels
#
# ..\data\res\Potholes and RoadCracks\Potholes and RoadCracks\test\images
#   docs 369 files
#
# ..\data\res\Potholes and RoadCracks\Potholes and RoadCracks\test\labels
#   docs 369 files
#
# ..\data\res\Potholes and RoadCracks\Potholes and RoadCracks\train
#   file images
#   file labels
#
# ..\data\res\Potholes and RoadCracks\Potholes and RoadCracks\train\images
#   docs 5667 files
#
# ..\data\res\Potholes and RoadCracks\Potholes and RoadCracks\train\labels
#   docs 5667 files
#
# ..\data\res\Potholes and RoadCracks\Potholes and RoadCracks\valid
#   file images
#   file labels
#
# ..\data\res\Potholes and RoadCracks\Potholes and RoadCracks\valid\images
#   docs 1219 files
#
# ..\data\res\Potholes and RoadCracks\Potholes and RoadCracks\valid\labels
#   docs 1219 files

# %%
class YOLODatasetAnalyzer:
    """Comprehensive YOLO dataset analyzer for EDA"""
    
    def __init__(self, dataset_path, class_names):
        self.dataset_path = Path(dataset_path)
        self.class_names = class_names
        self.stats = defaultdict(list)

    def find_images_and_labels(self):
        """Find all images and labels in dataset"""
        self.image_files = []
        self.label_files = []

        # Search for images
        for ext in ['*.jpg', '*.jpeg', '*.png', '*.JPG', '*.PNG']:
            self.image_files.extend(list(self.dataset_path.rglob(ext)))

        # Search for labels
        self.label_files = list(self.dataset_path.rglob('*.txt'))

        print(f"Found {len(self.image_files)} images")
        print(f"Found {len(self.label_files)} label files")

        return self.image_files, self.label_files

    def analyze_dataset(self):
        """Perform comprehensive EDA"""
        self.find_images_and_labels()

        class_counts = Counter()
        bbox_counts = []
        image_with_labels = 0
        bbox_sizes = []

        for label_file in tqdm(self.label_files, desc="Analyzing labels"):
            try:
                with open(label_file, 'r') as f:
                    lines = f.readlines()
                    if lines:
                        image_with_labels += 1
                        bbox_counts.append(len(lines))

                        for line in lines:
                            parts = line.strip().split()
                            if len(parts) >= 5:
                                class_id = int(parts[0])
                                class_counts[class_id] += 1
                                w, h = float(parts[3]), float(parts[4])
                                bbox_sizes.append((w, h))
            except Exception as e:
                print(f"Error reading {label_file}: {e}")

        self.class_counts = class_counts
        self.bbox_counts = bbox_counts
        self.bbox_sizes = bbox_sizes

        return class_counts, bbox_counts, bbox_sizes

    def visualize_analysis(self):
        """Create comprehensive visualizations"""
        fig = plt.figure(figsize=(20, 12))

        # 1. Class Distribution
        plt.subplot(2, 3, 1)
        classes = [self.class_names[i] for i in sorted(self.class_counts.keys())]
        counts = [self.class_counts[i] for i in sorted(self.class_counts.keys())]

        plt.barh(classes, counts, color='steelblue')
        plt.xlabel('Number of Instances', fontsize=12)
        plt.title('Class Distribution', fontsize=14, fontweight='bold')

        for i, v in enumerate(counts):
            plt.text(v, i, f' {v}', va='center', fontsize=10)

        # 2. Class Distribution Pie Chart
        plt.subplot(2, 3, 2)
        plt.pie(counts, labels=classes, autopct='%1.1f%%', startangle=90)
        plt.title('Class Distribution (%)', fontsize=14, fontweight='bold')

        # 3. Objects per Image
        plt.subplot(2, 3, 3)
        plt.hist(self.bbox_counts, bins=30, color='coral', edgecolor='black')
        plt.xlabel('Number of Objects per Image', fontsize=12)
        plt.ylabel('Frequency', fontsize=12)
        plt.title(f'Objects per Image\n(Avg: {np.mean(self.bbox_counts):.2f})',
                  fontsize=14, fontweight='bold')

        # 4. Bounding Box Width Distribution
        plt.subplot(2, 3, 4)
        widths = [w for w, h in self.bbox_sizes]
        plt.hist(widths, bins=50, color='lightgreen', edgecolor='black', alpha=0.7)
        plt.xlabel('Normalized Width', fontsize=12)
        plt.ylabel('Frequency', fontsize=12)
        plt.title('Bounding Box Width Distribution', fontsize=14, fontweight='bold')

        # 5. Bounding Box Height Distribution
        plt.subplot(2, 3, 5)
        heights = [h for w, h in self.bbox_sizes]
        plt.hist(heights, bins=50, color='lightcoral', edgecolor='black', alpha=0.7)
        plt.xlabel('Normalized Height', fontsize=12)
        plt.ylabel('Frequency', fontsize=12)
        plt.title('Bounding Box Height Distribution', fontsize=14, fontweight='bold')

        # 6. Summary Statistics
        plt.subplot(2, 3, 6)
        plt.axis('off')

        total_images = len(self.image_files)
        total_labels = len(self.label_files)
        total_objects = sum(counts)

        summary_text = f"""
        📊 DATASET SUMMARY
        {'='*40}

        Total Images: {total_images}
        Total Label Files: {total_labels}
        Total Objects: {total_objects}

        Number of Classes: {len(self.class_counts)}

        Avg Objects/Image: {np.mean(self.bbox_counts):.2f}
        Max Objects/Image: {max(self.bbox_counts)}
        Min Objects/Image: {min(self.bbox_counts)}

        Most Common Class: 
        {self.class_names[max(self.class_counts, key=self.class_counts.get)]}
        ({max(counts)} instances)

        Least Common Class: 
        {self.class_names[min(self.class_counts, key=self.class_counts.get)]}
        ({min(counts)} instances)
        """

        plt.text(0.1, 0.5, summary_text, fontsize=10, family='monospace',
                verticalalignment='center')

        plt.tight_layout()
        plt.savefig(OUTPUT_PATH / 'plots' / 'eda_analysis.png', dpi=300, bbox_inches='tight')
        plt.show()

        return {
            'total_images': total_images,
            'total_objects': total_objects,
            'class_counts': self.class_counts,
        }

    def visualize_samples(self, num_samples=6):
        """Visualize random samples with annotations"""
        fig, axes = plt.subplots(2, 3, figsize=(18, 12))
        axes = axes.ravel()

        samples = random.sample(self.image_files, min(num_samples, len(self.image_files)))
        colors = plt.cm.tab10(np.linspace(0, 1, len(self.class_names)))

        for idx, img_path in enumerate(samples):
            # Find corresponding label
            label_path = img_path.with_suffix('.txt')
            if not label_path.exists():
                label_path = Path(str(img_path).replace('images', 'labels').replace(img_path.suffix, '.txt'))

            # Read image
            img = cv2.imread(str(img_path))
            if img is None:
                continue
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            h, w = img.shape[:2]

            # Draw annotations
            if label_path.exists():
                with open(label_path, 'r') as f:
                    for line in f.readlines():
                        parts = line.strip().split()
                        if len(parts) >= 5:
                            class_id = int(parts[0])
                            x_center, y_center, width, height = map(float, parts[1:5])

                            # Convert to pixel coordinates
                            x1 = int((x_center - width/2) * w)
                            y1 = int((y_center - height/2) * h)
                            x2 = int((x_center + width/2) * w)
                            y2 = int((y_center + height/2) * h)

                            # Draw bbox
                            color = (np.array(colors[class_id][:3]) * 255).astype(int)
                            cv2.rectangle(img, (x1, y1), (x2, y2), color.tolist(), 2)

                            # Add label
                            label = self.class_names[class_id]
                            cv2.putText(img, label, (x1, y1-10),
                                      cv2.FONT_HERSHEY_SIMPLEX, 0.5, color.tolist(), 2)

            axes[idx].imshow(img)
            axes[idx].axis('off')
            axes[idx].set_title(f'Sample {idx+1}', fontsize=12, fontweight='bold')

        plt.tight_layout()
        plt.savefig(OUTPUT_PATH / 'plots' / 'sample_images.png', dpi=300, bbox_inches='tight')
        plt.show()

# %%
class_names = {
    0: "Damaged Road",
    1: "Pothole",
    2: "Illegal Parking",
    3: "Broken Road Sign",
    4: "Fallen Trees",
    5: "Littering/Garbage",
    6: "Vandalism",
    7: "Dead Animal",
    8: "Damaged Concrete",
    9: "Damaged Electric"
}

# Initialize analyzer
analyzer = YOLODatasetAnalyzer(dataset_path, class_names)

# Run analysis
print("\n Analyzing dataset...")
class_counts, bbox_counts, bbox_sizes = analyzer.analyze_dataset()

print("\n Visualizing analysis...")
stats = analyzer.visualize_analysis()

print("\n Visualizing samples...")
analyzer.visualize_samples(num_samples=6)
# Out:
#  Analyzing dataset...
# Found 94280 images
# Found 47142 label files
# Analyzing labels:  15%|█▌        | 7269/47142 [01:46<08:02, 82.68it/s]
# Error reading ..\data\res\IllegalParking\IllegalParking\README.dataset.txt: invalid literal for int() with base 10: '#'
# Error reading ..\data\res\IllegalParking\IllegalParking\README.roboflow.txt: invalid literal for int() with base 10: 'Illegal'
# Analyzing labels:  53%|█████▎    | 24929/47142 [05:42<04:09, 89.15it/s]
# Error reading ..\data\res\DamagedRoadSigns\DamagedRoadSigns\README.dataset.txt: invalid literal for int() with base 10: '#'
# Error reading ..\data\res\DamagedRoadSigns\DamagedRoadSigns\README.roboflow.txt: invalid literal for int() with base 10: 'damaged'
# Analyzing labels: 100%|██████████| 47142/47142 [11:23<00:00, 68.99it/s]
#  Visualizing analysis...
# C:\Users\Ilham\AppData\Local\Temp\ipykernel_12684\1972862233.py:138: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans Mono.
#   plt.tight_layout()
# C:\Users\Ilham\AppData\Local\Temp\ipykernel_12684\1972862233.py:139: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans Mono.
#   plt.savefig(OUTPUT_PATH / 'plots' / 'eda_analysis.png', dpi=300, bbox_inches='tight')
# c:\Users\Ilham\Documents\Projects\YOLO\YOLO-Project\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans Mono.
#   fig.canvas.print_figure(bytes_io, **kw)
#  Visualizing samples...

# %%
print("\n🔧 Reorganizing dataset structure for YOLO...")

# Define class mapping
class_mapping = {
    'Potholes and RoadCracks': 0,
    'IllegalParking': 2,
    'DamagedRoadSigns': 3,
    'FallenTrees': 4,
    'Garbage': 5,
    'Graffitti': 6,
    'DeadAnimalsPollution': 7,
    'Damaged concrete structures': 8,
    'DamagedElectricalPoles': 9,
}

# Create organized dataset structure in working directory
organized_path = Path('../data/processed')
for split in ['train', 'valid', 'test']:
    (organized_path / split / 'images').mkdir(parents=True, exist_ok=True)
    (organized_path / split / 'labels').mkdir(parents=True, exist_ok=True)

print("📁 Created organized dataset structure")
# Out:
# 🔧 Reorganizing dataset structure for YOLO...
# 📁 Created organized dataset structure

# %%
def reorganize_dataset(source_path, dest_path, class_mapping):
    """Reorganize dataset from class-separated folders to unified structure"""
    stats = {
        'train': {'images': 0, 'labels': 0},
        'valid': {'images': 0, 'labels': 0},
        'test': {'images': 0, 'labels': 0}
    }

    source_path = Path(source_path)
    dest_path = Path(dest_path)

    for class_folder_name, class_id in class_mapping.items():
        print(f"\n📦 Processing: {class_folder_name} (Class ID: {class_id})")

        class_folders = list(source_path.rglob(class_folder_name))

        if not class_folders:
            print(f"  ⚠️ Warning: Folder '{class_folder_name}' not found")
            continue

        class_folder = max(class_folders, key=lambda p: len(p.parts))

        for split in ['train', 'valid', 'test']:
            split_path = class_folder / split

            if not split_path.exists():
                print(f"  ⚠️ {split} folder not found")
                continue

            images_path = split_path / 'images'
            labels_path = split_path / 'labels'

            if images_path.exists():
                image_files = list(images_path.glob('*.[jp][pn]g')) + \
                             list(images_path.glob('*.jpeg'))

                for img_file in image_files:
                    new_name = f"{class_folder_name.replace(' ', '_')}_{img_file.name}"
                    dest_img = dest_path / split / 'images' / new_name

                    shutil.copy2(img_file, dest_img)
                    stats[split]['images'] += 1

                    label_file = labels_path / (img_file.stem + '.txt')
                    if label_file.exists():
                        dest_label = dest_path / split / 'labels' / \
                                    (new_name.rsplit('.', 1)[0] + '.txt')

                        with open(label_file, 'r') as f:
                            lines = f.readlines()

                        updated_lines = []
                        for line in lines:
                            parts = line.strip().split()
                            if len(parts) >= 5:
                                parts[0] = str(class_id)
                                updated_lines.append(' '.join(parts) + '\n')

                        with open(dest_label, 'w') as f:
                            f.writelines(updated_lines)

                        stats[split]['labels'] += 1

                print(f"  ✅ {split}: {len(image_files)} images")

    return stats

# %%
stats = reorganize_dataset(dataset_path, organized_path, class_mapping)
# Out:
# 📦 Processing: Potholes and RoadCracks (Class ID: 0)
#   ✅ train: 5667 images
#   ✅ valid: 1219 images
#   ✅ test: 369 images
#
# 📦 Processing: IllegalParking (Class ID: 2)
#   ✅ train: 57 images
#   ✅ valid: 3 images
#   ✅ test: 7 images
#
# 📦 Processing: DamagedRoadSigns (Class ID: 3)
#   ✅ train: 2267 images
#   ✅ valid: 43 images
#   ✅ test: 39 images
#
# 📦 Processing: FallenTrees (Class ID: 4)
#   ✅ train: 8500 images
#   ✅ valid: 982 images
#   ✅ test: 1632 images
#
# 📦 Processing: Garbage (Class ID: 5)
#   ✅ train: 3133 images
#   ✅ valid: 660 images
#   ✅ test: 337 images
#
# 📦 Processing: Graffitti (Class ID: 6)
#   ✅ train: 1704 images
#   ✅ valid: 214 images
#   ✅ test: 210 images
#
# 📦 Processing: DeadAnimalsPollution (Class ID: 7)
#   ✅ train: 172 images
#   ✅ valid: 32 images
#   ✅ test: 16 images
#
# 📦 Processing: Damaged concrete structures (Class ID: 8)
#   ✅ train: 9315 images
#   ✅ valid: 1228 images
#   ✅ test: 1222 images
#
# 📦 Processing: DamagedElectricalPoles (Class ID: 9)
#   ✅ train: 7271 images
#   ✅ valid: 513 images
#   ✅ test: 328 images

# %%
data_yaml_content = {
    'path': str(organized_path),
    'train': 'train/images',
    'val': 'valid/images',
    'test': 'test/images',
    'nc': 10,
    'names': {
        0: 'Damaged Road issues',
        1: 'Pothole Issues',
        2: 'Illegal Parking Issues',
        3: 'Broken Road Sign Issues',
        4: 'Fallen trees',
        5: 'Littering/Garbage on Public Places',
        6: 'Vandalism Issues',
        7: 'Dead Animal Pollution',
        8: 'Damaged concrete structures',
        9: 'Damaged Electric wires and poles'
    }
}

yaml_path =  Path('../config/data.yaml')
with open(yaml_path, 'w') as f:
    yaml.dump(data_yaml_content, f, sort_keys=False, default_flow_style=False)

print(f"\n✅ Created data.yaml at {yaml_path}")
print("\n📄 Content:")
with open(yaml_path, 'r') as f:
    print(f.read())

# Verify structure
print("\n🔍 Verifying organized dataset structure:")
for split in ['train', 'valid', 'test']:
    img_count = len(list((organized_path / split / 'images').glob('*')))
    lbl_count = len(list((organized_path / split / 'labels').glob('*.txt')))
    print(f"{split}: {img_count} images, {lbl_count} labels")
# Out:
# ✅ Created data.yaml at ..\config\data.yaml
#
# 📄 Content:
# path: ..\data\processed
# train: train/images
# val: valid/images
# test: test/images
# nc: 10
# names:
#   0: Damaged Road issues
#   1: Pothole Issues
#   2: Illegal Parking Issues
#   3: Broken Road Sign Issues
#   4: Fallen trees
#   5: Littering/Garbage on Public Places
#   6: Vandalism Issues
#   7: Dead Animal Pollution
#   8: Damaged concrete structures
#   9: Damaged Electric wires and poles
#
#
# 🔍 Verifying organized dataset structure:
# train: 38086 images, 38084 labels
# valid: 4894 images, 4894 labels
# test: 4160 images, 4160 labels

# %%
print("\n🚀 Starting YOLOv12 Training...")

# Initialize YOLOv12 model
model = YOLO("yolo12n.pt")  # Nano version for faster training

# Train the model
results = model.train(
    data=yaml_path,
    epochs=10,  # Increase for better results
    imgsz=640,
    batch=64,
    name='urban_issues_detector',
    patience=5,
    save=True,
    plots=True,
    val=True,
    project=str(OUTPUT_PATH / 'runs'),
    # device=cpu # using 2 devices
)

print("\n✅ Training completed!")
# Out:
# 🚀 Starting YOLOv12 Training...
# New https://pypi.org/project/ultralytics/8.3.237 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.235  Python-3.13.9 torch-2.6.0+cpu CPU (12th Gen Intel Core i5-12450HX)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=64, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=..\config\data.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=10, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo12n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=urban_issues_detector, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=5, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=..\outputs\runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\Ilham\Documents\Projects\YOLO\YOLO-Project\outputs\runs\urban_issues_detector, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to 'C:\Users\Ilham\AppData\Roaming\Ultralytics\Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 930.5KB/s 0.8s.7s<0.2s6s
# Overriding model.yaml nc=80 with nc=10
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  2    180864  ultralytics.nn.modules.block.A2C2f           [128, 128, 2, True, 4]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  2    689408  ultralytics.nn.modules.block.A2C2f           [256, 256, 2, True, 1]
#   9                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  10             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  11                  -1  1     86912  ultralytics.nn.modules.block.A2C2f           [384, 128, 1, False, -1]
#  12                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  13             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  14                  -1  1     24000  ultralytics.nn.modules.block.A2C2f           [256, 64, 1, False, -1]
#  15                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  16            [-1, 11]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  1     74624  ultralytics.nn.modules.block.A2C2f           [192, 128, 1, False, -1]
#  18                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  19             [-1, 8]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  21        [14, 17, 20]  1    432622  ultralytics.nn.modules.head.Detect           [10, [64, 128, 256]]
# YOLOv12n summary: 272 layers, 2,569,998 parameters, 2,569,982 gradients, 6.5 GFLOPs
#
# Transferred 640/691 items from pretrained weights
# Freezing layer 'model.21.dfl.conv.weight'
# train: Fast image access  (ping: 0.10.1 ms, read: 3.31.0 MB/s, size: 55.4 KB)
# train: Scanning C:\Users\Ilham\Documents\Projects\YOLO\YOLO-Project\data\processed\train\labels... 38084 images, 356 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 38086/38086 288.0it/s 2:12<0.0s
# train: C:\Users\Ilham\Documents\Projects\YOLO\YOLO-Project\data\processed\train\images\Damaged_concrete_structures_1692177626170_jpg.rf.0405b6db52c987df8de37893a39380f7.jpg: 1 duplicate labels removed
# train: C:\Users\Ilham\Documents\Projects\YOLO\YOLO-Project\data\processed\train\images\Damaged_concrete_structures_dacl10k_v2_train_0518_jpg.rf.4f5bd61589586a072d7e3a0a2582f65d.jpg: 1 duplicate labels removed
# train: C:\Users\Ilham\Documents\Projects\YOLO\YOLO-Project\data\processed\train\images\Damaged_concrete_structures_dacl10k_v2_train_0618_jpg.rf.dfe48b7f5fe880584d9ea2fb92243408.jpg: 1 duplicate labels removed
# train: C:\Users\Ilham\Documents\Projects\YOLO\YOLO-Project\data\processed\train\images\Damaged_concrete_structures_dacl10k_v2_train
jpg: 1 duplicate labels removed
# val: C:\Users\Ilham\Documents\Projects\YOLO\YOLO-Project\data\processed\valid\images\Damaged_concrete_structures_dacl10k_v2_train_3739_jpg.rf.da648672d14412e9033a334af2d012a5.jpg: 1 duplicate labels removed
# val: C:\Users\Ilham\Documents\Projects\YOLO\YOLO-Project\data\processed\valid\images\Damaged_concrete_structures_dacl10k_v2_train_3807_jpg.rf.797a291b6089ae8dc3fd829ba5ac5d82.jpg: 2 duplicate labels removed
# val: C:\Users\Ilham\Documents\Projects\YOLO\YOLO-Project\data\processed\valid\images\Damaged_concrete_structures_dacl10k_v2_train_3850_jpg.rf.2ce8615320535229f26acc3c1388888b.jpg: 1 duplicate labels removed
# val: C:\Users\Ilham\Documents\Projects\YOLO\YOLO-Project\data\processed\valid\images\Damaged_concrete_structures_dacl10k_v2_train_3900_jpg.rf.055a45c20eb3cc5a48f2a0e575343bd8.jpg: 9 duplicate labels removed
# val: C:\Users\Ilham\Documents\Projects\YOLO\YOLO-Project\data\processed\valid\images\Damaged_concrete_structures_dacl10k_v2_train_4079_jpg.rf.e3fb444ef3b95ceda3ecfe8af7ed8921.jpg: 1 duplicate labels removed
# val: C:\Users\Ilham\Documents\Projects\YOLO\YOLO-Project\data\processed\valid\images\Damaged_concrete_structures_dacl10k_v2_train_4362_jpg.rf.d8b28d8744f3c6c40a1e039d32234f78.jpg: 1 duplicate labels removed
# val: C:\Users\Ilham\Documents\Projects\YOLO\YOLO-Project\data\processed\valid\images\Damaged_concrete_structures_dacl10k_v2_train_4756_jpg.rf.8929a14c13621e447b9a3ba5653df445.jpg: 1 duplicate labels removed
# val: C:\Users\Ilham\Documents\Projects\YOLO\YOLO-Project\data\processed\valid\images\Damaged_concrete_structures_dacl10k_v2_train_4843_jpg.rf.0df80e2650f01f1106fcdb4570d78cb3.jpg: 4 duplicate labels removed
# val: C:\Users\Ilham\Documents\Projects\YOLO\YOLO-Project\data\processed\valid\images\Damaged_concrete_structures_dacl10k_v2_train_4854_jpg.rf.d331c90e7ade6e70521558610802d32e.jpg: 1 duplicate labels removed
# val: C:\Users\Ilham\Documents\Projects\YOLO\YOLO-Project\data\processed\valid\images\Damaged_concrete_structures_dacl10k_v2_train_6113_jpg.rf.533aee1bca853b88023cefc1f1dd0985.jpg: 1 duplicate labels removed
# val: C:\Users\Ilham\Documents\Projects\YOLO\YOLO-Project\data\processed\valid\images\Damaged_concrete_structures_dacl10k_v2_train_6184_jpg.rf.2eb60dd97dba5f2f3329cca531e19b9d.jpg: 1 duplicate labels removed
# val: C:\Users\Ilham\Documents\Projects\YOLO\YOLO-Project\data\processed\valid\images\Damaged_concrete_structures_dacl10k_v2_train_6392_jpg.rf.d8d8e41e923308213e4d382fa54c1433.jpg: 1 duplicate labels removed
# val: C:\Users\Ilham\Documents\Projects\YOLO\YOLO-Project\data\processed\valid\images\Damaged_concrete_structures_dacl10k_v2_train_6926_jpg.rf.40c2839a19955092706c11e68ee664b5.jpg: 1 duplicate labels removed
# val: C:\Users\Ilham\Documents\Projects\YOLO\YOLO-Project\data\processed\valid\images\Damaged_concrete_structures_dacl10k_v2_validation_0691_jpg.rf.0b1afb97348960219a9875b68f91ef99.jpg: 1 duplicate labels removed
# val: New cache created: C:\Users\Ilham\Documents\Projects\YOLO\YOLO-Project\data\processed\valid\labels.cache
# WARNING Box and segment counts should be equal, but got len(segments) = 9576, len(boxes) = 15731. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# Plotting labels to C:\Users\Ilham\Documents\Projects\YOLO\YOLO-Project\outputs\runs\urban_issues_detector\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000714, momentum=0.9) with parameter groups 113 weight(decay=0.0), 120 weight(decay=0.0005), 119 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to C:\Users\Ilham\Documents\Projects\YOLO\YOLO-Project\outputs\runs\urban_issues_detector
# Starting training for 10 epochs...
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/10         0G      1.753      3.802      1.867        178        640: 43% ━━━━━─────── 255/596 44.3s/it 3:45:43<4:11:40
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
print("\n📊 Evaluating model...")

# Validate the model
model = YOLO("../outputs/models/best.pt")
metrics = model.val()

# Extract metrics
map50 = metrics.box.map50
map50_95 = metrics.box.map
precision = metrics.box.mp
recall = metrics.box.mr

# Print metrics
print("\n" + "="*50)
print("📈 MODEL PERFORMANCE METRICS")
print("="*50)
print(f"mAP@50:     {map50:.4f}")
print(f"mAP@50-95:  {map50_95:.4f}")
print(f"Precision:  {precision:.4f}")
print(f"Recall:     {recall:.4f}")
print("="*50)

# Create metrics DataFrame
metrics_df = pd.DataFrame({
    'Metric': ['mAP@50', 'mAP@50-95', 'Precision', 'Recall'],
    'Value': [map50, map50_95, precision, recall]
})

print("\n📊 Metrics DataFrame:")
print(metrics_df)

# Visualize metrics
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Bar plot
axes[0].bar(metrics_df['Metric'], metrics_df['Value'], 
           color=['#3498db', '#e74c3c', '#2ecc71', '#f39c12'])
axes[0].set_ylabel('Score', fontsize=12)
axes[0].set_title('Model Performance Metrics', fontsize=14, fontweight='bold')
axes[0].set_ylim(0, 1)
axes[0].grid(axis='y', alpha=0.3)

for i, v in enumerate(metrics_df['Value']):
    axes[0].text(i, v + 0.02, f'{v:.4f}', ha='center', va='bottom', fontweight='bold')

# Radar chart
categories = metrics_df['Metric'].tolist()
values = metrics_df['Value'].tolist()
values += values[:1]

angles = np.linspace(0, 2 * np.pi, len(categories), endpoint=False).tolist()
angles += angles[:1]

ax = plt.subplot(122, projection='polar')
ax.plot(angles, values, 'o-', linewidth=2, color='#3498db')
ax.fill(angles, values, alpha=0.25, color='#3498db')
ax.set_xticks(angles[:-1])
ax.set_xticklabels(categories)
ax.set_ylim(0, 1)
ax.set_title('Performance Radar Chart', fontsize=14, fontweight='bold', pad=20)
ax.grid(True)

plt.tight_layout()
plt.savefig(OUTPUT_PATH / 'model_metrics.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# 📊 Evaluating model...
# Ultralytics 8.3.235  Python-3.13.9 torch-2.6.0+cpu CPU (12th Gen Intel Core i5-12450HX)
# YOLOv12n summary (fused): 159 layers, 2,558,678 parameters, 0 gradients, 6.3 GFLOPs
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 5
#       3 # Validate the model
#       4 model = YOLO("../outputs/models/best.pt")
# ----> 5 metrics = model.val()
#       7 # Extract metrics
#       8 map50 = metrics.box.map50
#
# File c:\Users\Ilham\Documents\Projects\YOLO\YOLO-Project\venv\Lib\site-packages\ultralytics\engine\model.py:611, in Model.val(self, validator, **kwargs)
#     608 args = {**self.overrides, **custom, **kwargs, "mode": "val"}  # highest priority args on the right
#     610 validator = (validator or self._smart_load("validator"))(args=args, _callbacks=self.callbacks)
# --> 611 validator(model=self.model)
#     612 self.metrics = validator.metrics
#     613 return validator.metrics
#
# File c:\Users\Ilham\Documents\Projects\YOLO\YOLO-Project\venv\Lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File c:\Users\Ilham\Documents\Projects\YOLO\YOLO-Project\venv\Lib\site-packages\ultralytics\engine\validator.py:175, in BaseValidator.__call__(self, trainer, model)
#     172     LOGGER.info(f"Setting batch={self.args.batch} input of shape ({self.args.batch}, 3, {imgsz}, {imgsz})")
#     174 if str(self.args.data).rsplit(".", 1)[-1] in {"yaml", "yml"}:
# --> 175     self.data = check_det_dataset(self.args.data)
#     176 elif self.args.task == "classify":
#     177     self.data = check_cls_dataset(self.args.data, split=self.args.split)
#
# File c:\Users\Ilham\Documents\Projects\YOLO\YOLO-Project\venv\Lib\site-packages\ultralytics\data\utils.py:400, in check_det_dataset(dataset, autodownload)
#     386 def check_det_dataset(dataset: str, autodownload: bool = True) -> dict[str, Any]:
#     387     """Download, verify, and/or unzip a dataset if not found locally.
#     388
#     389     This function checks the availability of a specified dataset, and if not found, it has the option to download and
#    (...)    398         (dict[str, Any]): Parsed dataset information and paths.
#     399     """
# --> 400     file = check_file(dataset)
#     402     # Download (optional)
#     403     extract_dir = ""
#
# File c:\Users\Ilham\Documents\Projects\YOLO\YOLO-Project\venv\Lib\site-packages\ultralytics\utils\checks.py:580, in check_file(file, suffix, download, download_dir, hard)
#     578 files = glob.glob(str(ROOT / "**" / file), recursive=True) or glob.glob(str(ROOT.parent / file))  # find file
#     579 if not files and hard:
# --> 580     raise FileNotFoundError(f"'{file}' does not exist")
#     581 elif len(files) > 1 and hard:
#     582     raise FileNotFoundError(f"Multiple files match '{file}', specify exact path: {files}")
#
# FileNotFoundError: '/kaggle/working/organized_dataset/data.yaml' does not exist

# %%
print("\n📊 Training Results Visualization...")

results_path = OUTPUT_PATH / 'plots'
if results_path.exists():
    print(f"Results saved in: {results_path}")

    plots = ['results.png', 'confusion_matrix.png', 'F1_curve.png', 'PR_curve.png']
    
    fig, axes = plt.subplots(2, 2, figsize=(20, 16))
    axes = axes.ravel()

    for idx, plot_name in enumerate(plots):
        plot_path = results_path / plot_name
        if plot_path.exists():
            img = plt.imread(plot_path)
            axes[idx].imshow(img)
            axes[idx].axis('off')
            axes[idx].set_title(plot_name.replace('.png', '').replace('_', ' ').title(),
                              fontsize=14, fontweight='bold')
        else:
            axes[idx].text(0.5, 0.5, f'{plot_name} not found',
                          ha='center', va='center', fontsize=12)
            axes[idx].axis('off')

    plt.tight_layout()
    plt.savefig(OUTPUT_PATH / 'plots'/ 'training_results.png', dpi=300, bbox_inches='tight')
    plt.show()
# Out:
# 📊 Training Results Visualization...
